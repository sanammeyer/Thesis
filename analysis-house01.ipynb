# %%
import pandas as pd
import numpy as np
from helper_functions import *
import matplotlib.pyplot as plt

# %%
df_house1 = pd.read_csv("C:/Users/sanam/Documents/NILM_datasets/merged_data_cleaned.csv", index_col=0)

# %%
df_house1.index = pd.to_datetime(df_house1.index)

# %%
df_cm = pd.DataFrame(df_house1['Coffee machine'])

# %%
plot_usage(df_cm.loc['2013-12-09'])
